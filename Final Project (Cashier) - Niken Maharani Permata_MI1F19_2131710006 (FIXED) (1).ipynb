// %% [markdown]
// ## Program Kasir Tiket Private Concert : TREASURE

// %%
import java.util.Scanner;
import java.util.Random;
Scanner scan = new Scanner(System.in);
Random r = new Random();

String alphabet = "123456789abcdefghijklmnopqrstuvwxyz",merchs,namaProduk,nama, jawab="";
long bayar, dsc,kembali, total;
int produk[] = new int [10];
int jumlah[] = new int [10];
int urutan = 0, i, hargaProduk, total=0, kode, harga, sisa,samaPajak,harga,sisa,pembayaran,kuota,quanty,totalQuanty;
String barang[][] = {{"","Tiket REG1", "Tiket REG2", "Tiket Gold", "Tiket VIP", "Tiket VVIP","Merch Hoodie", "Merch Totebag", "Merch Tumblr", "Merch HandFan"},
                    {"","2000000", "2500000", "3300000","4000000", "4300000","250000", "150000", "80000", "80000"},
                    {"","300", "300", "270", "200", "150","300", "300", "270", "200"}};
String tiket[][] = {{"","REG 1", "REG 2", "Gold", "VIP", "VVIP"},
                    {"","2000000", "2500000", "3300000","4000000", "4300000"},
                    {"", "300", "300", "270", "200", "150"}};
String merch[][] = {{"","Hoodie", "Totebag", "Tumblr", "HandFan"}, 
                    {"","250000", "150000", "80000", "80000"},
                    {"300", "300", "270", "200", "150"}};

    static void barangJual(){
        System.out.println("LIST PRODUK\t\tHARGA\t\t\tKUOTA");
           System.out.println("------------------------------------------------------------------");
        int var1 = 0;
        int var2 = 1;
        int var3 = 2;
        for (int i = 1; i < barang[var1].length; i++){
            System.out.println(i + "."+ barang[var1][i]+ "\t\t Rp."+ barang[var2][i]+ "\t\tkuota "+barang[var3][i]);
        }  System.out.println();
    }

    static void tiket(){
        System.out.println("Tipe Seat\tHarga\t\t\tKapasitas");
        int var1 = 0;
        int var2 = 1;
        int var3 = 2;
        for (int i = 1; i < tiket[var1].length; i++){
            System.out.println(i + "."+ tiket[var1][i]+ "\t\t Rp."+ tiket [var2][i]+ "\t\t "+tiket[var3][i]+" tiket");
        }  System.out.println();
        }
   
    static void merch(){
    System.out.println("Daftar Merchandise\tHarga\t\t\tKuota");
        int var1 = 0;
        int var2 = 1;
        int var3 = 2;
            for (int i = 1; i < merch[var1].length; i++){
            System.out.println(i + "."+ merch[var1][i]+ "\t\t Rp."+ merch[var2][i]+ "\t\t "+merch[var3][i]);
        }  System.out.println();
    }

     static void kembalian(){
        if (bayar < dsc){
            long kurang = dsc-bayar;
            System.out.println("Uang yang anda masukkan tidak cukup. Jumlah kekurangan : Rp "+kurang);
            System.out.print("Masukan uang yang kembali : ");
            int tambahan = scan.nextInt();
            bayar = tambahan;   
        } kembali = bayar - dsc;
        System.out.println("Jumlah kembalian : Rp "+kembali);
        System.out.println();
     }
        

    static int sisaTiket(){
        sisa = kuota-quanty;
        System.out.print(sisa);
        return sisa;
    }

    static void ReferralCode(){
        System.out.println("++++++++++++++++++++++++++++++++++++++");
        System.out.print("\tREFERRAL CODE : ");
        for (int x = 0; x < 6; x++) {
            System.out.print(alphabet.charAt(r.nextInt(alphabet.length())));
        } System.out.println("");
        System.out.println("++++++++++++++++++++++++++++++++++++++");
        System.out.println("\n");
        System.out.println("Kesempatan mendapatkan free merchandise + private fanmeeting bersama TREASURE");
        System.out.println("dengan menukarkan kode ini pada saat memasuki venue");
        System.out.println("Pemenang akan diumumkan pada saat pelaksanaan konser melalui sistem acak di akhir acara");
    }

static void pembelian(){
System.out.print("Nama Pembeli : ");
scan.nextLine();
nama= scan.nextLine();
System.out.println();
barangJual();
do{
    System.out.print("Tulis Angka Tiket / Merchandise yang hendak dipilih : ");
    produk[urutan]= scan.nextInt();
    System.out.print("Jumlah produk : ");
    jumlah[urutan]=scan.nextInt();
    System.out.print("Tambah data lagi? y/n : ");
    scan.nextLine();
    jawab=scan.nextLine();
    urutan++;
    System.out.println();
} while (jawab.equalsIgnoreCase("y") & urutan < 10);

    System.out.println("--------------------------------------------------------------------------------------------");
    System.out.println("                               -     STRUK PEMBELIAN     -                                  ");
    System.out.println("--------------------------------------------------------------------------------------------");
    System.out.println("Code |   Nama Barang    |     Jumlah     |     Harga     |      Total    |    Sisa Kuota   |");
for(int i=0; i<urutan;i++){
    namaProduk="";
    if(produk[i]==1){
        namaProduk="REG 1";
    } else if(produk[i]==2){
        namaProduk="REG 2";
    } else if(produk[i]==3){
        namaProduk="GOLD";
    }else if(produk[i]==4){
        namaProduk="VIP";
    }else if(produk[i]==5){
        namaProduk="VVIP";
    }else if(produk[i]==6){
        namaProduk="Hoodie";
    }else if(produk[i]==7){
        namaProduk="Totebag";
    } else if(produk[i]==8){
        namaProduk="Tumblr";
    } else if(produk[i]==9){
        namaProduk="HandFan";
    }
    
    long hargaProduk = 0;
    if (produk[i]==1){
        hargaProduk=2000000;
    } else if(produk[i]==2){
        hargaProduk=2500000;
    } else if (produk[i]==3){
        hargaProduk=3300000;
    } else if (produk[i]==4){
        hargaProduk=4000000;
    } else if (produk[i]==5){
        hargaProduk=4300000;
    } else if (produk[i]==6){
        hargaProduk=250000;
    } else if (produk[i]==7){
        hargaProduk=150000;
    } else if (produk[i]==8){
        hargaProduk=80000;
    } else if (produk[i]==9){
        hargaProduk=80000;
    }
    
    kuota = 0;
    if (produk[i]==1){
        kuota=300;
    } else if(produk[i]==2){
        kuota=300;
    } else if (produk[i]==3){
        kuota=270;
    } else if (produk[i]==4){
        kuota=200;
    } else if (produk[i]==5){
        kuota=150;
    } else if (produk[i]==6){
        kuota=300;
    } else if (produk[i]==7){
        kuota=300;
    } else if (produk[i]==8){
        kuota=270;
    } else if (produk[i]==9){
        kuota=200;
    }
    
    quanty=jumlah[i];
    bayar = hargaProduk*quanty;
    System.out.println((i+1)+"\t"+namaProduk+"\t\t       "+jumlah[i]+"\t     Rp "+hargaProduk+"\t    Rp "+bayar+"\t\t"+sisaTiket());
    total+=bayar;
    totalQuanty+=quanty;
}   int samaPajak = total+(total*10/100);
    System.out.println();
    System.out.println("Pembelian atas nama : "+nama); 
    System.out.println("Jumlah item : "+totalQuanty);
    System.out.println("Total yang harus dibayarkan : Rp " +samaPajak);
    System.out.println("Sudah termasuk PAJAK 10%");
    System.out.println();
    System.out.println(" Jenis Pembayaran ");
    System.out.println("1. Tunai");
    System.out.println("2. Transfer Bank");
    System.out.println("3. e-Wallet / e-Money");
    System.out.print("Pilih jenis pembayaran yang diinginkan : ");
    pembayaran = scan.nextInt();
    System.out.println("---------------------------------------------------------------------------------------");

if(pembayaran == 1){
    dsc = samaPajak;
    System.out.println("Anda tidak mendapatkan diskon");
    System.out.print("Total yang harus dibayarkan : "+dsc);
    System.out.println();
} else if (pembayaran==2){
    System.out.println("Anda mendapatkan diskon 15%");
    dsc = samaPajak*85/100;
    System.out.print("Total yang harus dibayarkan : "+dsc);
    System.out.println();
} else if (pembayaran==3){
    System.out.println("Anda mendapatkan diskon 20%");
    dsc = samaPajak*80/100;
    System.out.print("Total yang harus dibayarkan : Rp "+dsc);
    System.out.println();
}

System.out.print("Jumlah Bayar : Rp ");
bayar = scan.nextLong();
kembalian();
ReferralCode();
}

        for (int i = 0; i < 23; i++){
            System.out.print("=");
        }
        System.out.print("\tTREASURE'S PRIVATE CONCERT : INDONESIA\t");
        for (int i = 0; i < 23; i++){
            System.out.print("=");
        }
        System.out.println();
       
        System.out.print("\t\t\t\tTICKET RESERVATION\t\t\t\t");
        System.out.println();
        System.out.println("---------------------------------------------------------------------------------------");
       
int menu=0;
String repeat = "ya";

do{
    System.out.println(" MENU ");
    System.out.println("1. Daftar Seat");
    System.out.println("2. Merchandise");
    System.out.println("3. Pembelian Tiket");
    System.out.print("Pilih menu yang diinginkan : ");
    menu = scan.nextInt();
    System.out.println("---------------------------------------------------------------------------------------");

if(menu == 1){
    tiket();
    System.out.println("---------------------------------------------------------------------------------------");
} else if (menu==2){
    merch();
    System.out.println("---------------------------------------------------------------------------------------");
} else if (menu==3){
    pembelian();
    System.out.println("---------------------------------------------------------------------------------------");
} else {
} System.out.print("Apakah anda ingin memilih menu lain? ya/tidak : ");
    scan.nextLine();
    repeat = scan.nextLine();
    System.out.println("---------------------------------------------------------------------------------------");
}while(repeat.equalsIgnoreCase("ya"));
      
        for (int i = 0; i < 32; i++){
            System.out.print("=");
        }
        System.out.print("\tTERIMA KASIH\t");
        for (int i = 0; i < 32; i++){
            System.out.print("=");
        }
        System.out.println();
// Out:
// =======================	TREASURE'S PRIVATE CONCERT : INDONESIA	=======================
// 				TICKET RESERVATION
// ---------------------------------------------------------------------------------------
//  MENU
// 1. Daftar Seat
// 2. Merchandise
// 3. Pembelian Tiket
// Pilih menu yang diinginkan : 1
// ---------------------------------------------------------------------------------------
// Tipe Seat	Harga			Kapasitas
// 1.REG 1		 Rp.2000000		 300 tiket
// 2.REG 2		 Rp.2500000		 300 tiket
// 3.Gold		 Rp.3300000		 270 tiket
// 4.VIP		 Rp.4000000		 200 tiket
// 5.VVIP		 Rp.4300000		 150 tiket
//
// ---------------------------------------------------------------------------------------
// Apakah anda ingin memilih menu lain? ya/tidak : ya
// ---------------------------------------------------------------------------------------
//  MENU
// 1. Daftar Seat
// 2. Merchandise
// 3. Pembelian Tiket
// Pilih menu yang diinginkan : 2
// ...
